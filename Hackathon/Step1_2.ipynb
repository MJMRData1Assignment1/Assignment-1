# %% [markdown]
# # select data

# %%
import geopandas as gpd
import os
import pandas as pd

# %%
folder_dir = 'C:\\Users\\Admin\\Desktop\\Code\\Assignment-1\\Hackathon\\csv'
files = os.listdir(folder_dir)
print(files)
# Out:
# ['Housing.csv', 'Income.csv', 'Public spaces.csv', 'Safety.csv', 'Socio-economic status.csv', 'Traffic.csv']

# %%
Rent_Average = pd.read_csv(folder_dir+'\\Housing.csv')
Rent_Average.head()
# Out:
#   Geography                     Area Area code  Year    theme  Housing stock  \
# 0    Wijken          Haarlemmerbuurt        AA  2021  Housing           5654
# 1    Wijken                  Jordaan        AB  2021  Housing          13217
# 2    Wijken      Grachtengordel-West        AC  2021  Housing           4316
# 3    Wijken  Burgwallen-Nieuwe Zijde        AD  2021  Housing           2972
# 4    Wijken    Burgwallen-Oude Zijde        AE  2021  Housing           2974
#
#   Housing density Trailer space Mooring place Sheltered accommodations  ...  \
# 0           10558             4           135                       38  ...
# 1           15870             1           113                        6  ...
# 2            9638             1            75                        9  ...
# 3            5302             1            13                        5  ...
# 4            8535             -             3                       12  ...
#
#   Wish to move 65+ (%)  Neighbourhood: Satisfaction with neighbourhood (1-10)  \
# 0                   16                                                8.2
# 1                   14                                                8.2
# 2                   13                                                8.4
# 3                    -                                                7.2
# 4                    -                                                7.3
#
#   Neighbourhood: pleasant to live (1-10)  \
# 0                                      8
# 1                                    7.8
# 2                                      8
# 3                                    7.5
# 4                                    7.1
#
#   Neighbourhood: Expected development (1-10) Neighbourhood: % improved  \
# 0                                        7.2                        14
# 1                                          7                        15
# 2                                          7                        13
# 3                                        6.6                        26
# 4                                        6.6                        32
#
#    Neighbourhood: % stayed the same Neighbourhood: % deteriorated  \
# 0                                65                            16
# 1                                62                            18
# 2                                64                            19
# 3                                47                            18
# 4                                40                            22
#
#   Neighbourhood: feeling at home (1-10) Involvement neighbours (1-10)  \
# 0                                   8.3                           6.7
# 1                                   8.3                           6.8
# 2                                   8.4                           6.6
# 3                                   7.7                           5.7
# 4                                   7.8                           6.5
#
#   Rent: average in commercial sector
# 0                                  -
# 1                               1414
# 2                                  -
# 3                               1434
# 4                                  -
#
# [5 rows x 68 columns]

# %%
columns_list_1 = list(Rent_Average.columns)
columns_list_1
# Out:
# ['Geography',
#  'Area',
#  'Area code',
#  'Year',
#  'theme',
#  'Housing stock',
#  'Housing density',
#  'Trailer space',
#  'Mooring place',
#  'Sheltered accommodations',
#  'Property: Housing corporation',
#  'Property: Owner-occupied',
#  'Property: Private rent',
#  'Property: % Housing corporation',
#  'Property: % Private rent',
#  'Property: % Owner-occupied',
#  'Living space 0-40 m2',
#  'Living space 40-60 m2',
#  'Living space 60-80 m2',
#  'Living space 80-100 m2',
#  'Living space 100 m2+',
#  'Living space not stated',
#  'Living space: % 0 - 40 m2',
#  'Living space: % 40- 60 m2',
#  'Living space: % 60- 80 m2',
#  'Living space: % 80- 100 m2',
#  'Living space: % 100 m2+',
#  'Living space: % unknown',
#  'Average number of residents',
#  'Cramped living',
#  'Cramped living (%)',
#  'Cramped living children',
#  'Cramped living children (%)',
#  'House too small (%)',
#  'Residence too big (% 65+ years)',
#  'Housing for the elderly',
#  'Housing for the elderly (%)',
#  'Ground floor or elevator',
#  'Ground floor or elevator 75+',
#  'Ground floor or elevator (%75+)',
#  'Average house-value for tax purposes',
#  'Rent: average',
#  'Rent: % rent below deduction limit',
#  'Rent: % rent below subsidy limit',
#  'Rent: % middle',
#  'Rent: % high',
#  'Rent: % social (corporation)',
#  'Rent: % social (private sector)',
#  'Rent: % commercial (corporation)',
#  'Rent: % commercial (private sector)',
#  'Rent ratio',
#  'Affordabilaty home',
#  'Satisfaction with home',
#  'Satisfaction with corporation home',
#  'Satisfaction with home (65+ years)',
#  'Maintenance own home (1-10)',
#  'Maintenance housing in neighbourhood  (1-10)',
#  'Wish to move (%)',
#  'Wish to move 65+ (%)',
#  'Neighbourhood: Satisfaction with neighbourhood (1-10)',
#  'Neighbourhood: pleasant to live (1-10)',
#  'Neighbourhood: Expected development (1-10)',
#  'Neighbourhood: % improved',
#  'Neighbourhood: % stayed the same',
#  'Neighbourhood: % deteriorated',
#  'Neighbourhood: feeling at home (1-10)',
#  'Involvement neighbours (1-10)',
#  'Rent: average in commercial sector']

# %%
Rent_Average_Source = Rent_Average[['Geography','Area','Area code','Year','Rent: average','Average house-value for tax purposes']]
Rent_Average_Source.head()
# Out:
#   Geography                     Area Area code  Year Rent: average  \
# 0    Wijken          Haarlemmerbuurt        AA  2021           834
# 1    Wijken                  Jordaan        AB  2021           815
# 2    Wijken      Grachtengordel-West        AC  2021          1202
# 3    Wijken  Burgwallen-Nieuwe Zijde        AD  2021          1074
# 4    Wijken    Burgwallen-Oude Zijde        AE  2021           832
#
#   Average house-value for tax purposes
# 0                               553606
# 1                               492596
# 2                               871371
# 3                               488138
# 4                               488413

# %%
Public_Spaces = pd.read_csv(folder_dir+'\\Public spaces.csv')
Public_Spaces.head()
# Out:
#   Geography                     Area Area code  Year         theme  \
# 0    Wijken          Haarlemmerbuurt        AA  2021  Public space
# 1    Wijken                  Jordaan        AB  2021  Public space
# 2    Wijken      Grachtengordel-West        AC  2021  Public space
# 3    Wijken  Burgwallen-Nieuwe Zijde        AD  2021  Public space
# 4    Wijken    Burgwallen-Oude Zijde        AE  2021  Public space
#
#   Green spaces (1-10) Playing facilities (1-10)  \
# 0                 6.5                       6.9
# 1                 5.9                       6.2
# 2                 5.8                         6
# 3                 4.6                       4.3
# 4                 4.8                       4.8
#
#   Clean-up state  streets and pavements (1-10)  \
# 0                                          6.7
# 1                                          6.4
# 2                                          6.8
# 3                                            6
# 4                                            7
#
#   Clean-up state green spaces  (1-10)  \
# 0                                 6.7
# 1                                 6.3
# 2                                 6.4
# 3                                 5.4
# 4                                 5.9
#
#   Clean-up state playing facilities  (1-10)  ... Area public green (ha)  \
# 0                                       7.1  ...                   1.33
# 1                                       6.6  ...                   0.74
# 2                                       6.4  ...                      -
# 3                                       4.5  ...                   0.11
# 4                                       5.8  ...                   0.02
#
#   Area: % water Area: % buildings Nuisance: pollution (1-10)  \
# 0         34.57             32.75                          6
# 1         12.11             56.49                        5.7
# 2         20.71             58.06                        5.9
# 3         23.63             36.13                        4.7
# 4         13.88             57.19                        5.6
#
#    Neighbourhood clean (%) Neighbourhood dirty (%)  Area: % green  \
# 0                       38                      19           1.63
# 1                       38                      20           0.78
# 2                       39                      20              -
# 3                       30                      35           0.16
# 4                       22                      40           0.05
#
#   Area water (ha) Area land (ha) % Area land (ha)
# 0           28.16          53.29            65.43
# 1           11.46          83.19            87.89
# 2           11.78          45.12            79.29
# 3           17.21          55.63            76.37
# 4            5.62          34.85            86.12
#
# [5 rows x 25 columns]

# %%
Public_Spaces_Source = Public_Spaces[['Geography','Area','Area code','Area public green (ha)']]
Public_Spaces_Source.head()
# Out:
#   Geography                     Area Area code Area public green (ha)
# 0    Wijken          Haarlemmerbuurt        AA                   1.33
# 1    Wijken                  Jordaan        AB                   0.74
# 2    Wijken      Grachtengordel-West        AC                      -
# 3    Wijken  Burgwallen-Nieuwe Zijde        AD                   0.11
# 4    Wijken    Burgwallen-Oude Zijde        AE                   0.02

# %%
Traffic = pd.read_csv(folder_dir+'\\Traffic.csv', encoding='utf-8')
Traffic.head()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# File parsers.pyx:1120, in pandas._libs.parsers.TextReader._convert_tokens()
#
# File parsers.pyx:1272, in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# File parsers.pyx:1285, in pandas._libs.parsers.TextReader._string_convert()
#
# File parsers.pyx:1535, in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa8 in position 5: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 Traffic = pd.read_csv(folder_dir+'\\Traffic.csv', encoding='utf-8')
#       2 Traffic.head()
#
# File c:\Users\Admin\.conda\envs\gds\lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Admin\.conda\envs\gds\lib\site-packages\pandas\io\parsers\readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File c:\Users\Admin\.conda\envs\gds\lib\site-packages\pandas\io\parsers\readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File c:\Users\Admin\.conda\envs\gds\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File parsers.pyx:838, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File parsers.pyx:921, in pandas._libs.parsers.TextReader._read_rows()
#
# File parsers.pyx:1066, in pandas._libs.parsers.TextReader._convert_column_data()
#
# File parsers.pyx:1127, in pandas._libs.parsers.TextReader._convert_tokens()
#
# File parsers.pyx:1272, in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# File parsers.pyx:1285, in pandas._libs.parsers.TextReader._string_convert()
#
# File parsers.pyx:1535, in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa8 in position 5: invalid start byte

# %%
# find this solution via chat GPT
import chardet

with open(folder_dir+'\\Traffic.csv', 'rb') as file:
    raw_data = file.read()
    result = chardet.detect(raw_data)
    encoding = result['encoding']

print(result['encoding'])
# Out:
# ISO-8859-1

# %%
Traffic = pd.read_csv(folder_dir+'\\Traffic.csv', encoding='ISO-8859-1')
Traffic.to_csv(folder_dir+'\\Traffic.csv', index=False, encoding='utf-8')

Traffic = pd.read_csv(folder_dir+'\\Traffic.csv', encoding='utf-8')
Traffic.head()
# Out:
#   Geography                     Area Area code  Year    theme  \
# 0    Wijken          Haarlemmerbuurt        AA  2021  Traffic
# 1    Wijken                  Jordaan        AB  2021  Traffic
# 2    Wijken      Grachtengordel-West        AC  2021  Traffic
# 3    Wijken  Burgwallen-Nieuwe Zijde        AD  2021  Traffic
# 4    Wijken    Burgwallen-Oude Zijde        AE  2021  Traffic
#
#   Nuisance: speeding traffic (%)  \
# 0                             15
# 1                             17
# 2                             20
# 3                             18
# 4                             13
#
#   Nuisance: aggressive behaviour in traffic (%)  \
# 0                                            10
# 1                                            16
# 2                                            16
# 3                                            12
# 4                                            21
#
#   Nuisance: parking problems (%)  Parking spots total Parking spots fiscal  \
# 0                             10                 1112                  952
# 1                             21                 2711                 2409
# 2                             21                 1338                 1218
# 3                             16                  619                  382
# 4                             22                  310                  211
#
#    Parking spots non public Parking facilities (1-10)  \
# 0                       160                       5.9
# 1                       302                       5.5
# 2                       120                       5.4
# 3                       237                       5.5
# 4                        99                       5.2
#
#   Parking facilities bikes (1-10) Nuisance: parking (1-10)  \
# 0                             5.7                      6.9
# 1                             5.1                      6.5
# 2                             5.4                      6.2
# 3                             5.6                        7
# 4                             5.9                      6.6
#
#   Public transport (1-10) Public transport 65+ (1-10)  \
# 0                     7.6                         7.3
# 1                     7.7                         7.5
# 2                     7.9                         7.7
# 3                     8.5                         7.9
# 4                     8.5                         8.6
#
#   Nuisance: amount of traffic (1-10) Nuisance: traffic noise (1-10)  \
# 0                                6.8                            6.8
# 1                                6.6                            6.8
# 2                                6.8                            6.8
# 3                                6.4                            6.2
# 4                                6.7                            6.9
#
#   Parking spots non-fiscal
# 0                        -
# 1                        -
# 2                        -
# 3                        -
# 4                        -

# %%
Traffic_Source = Traffic[['Geography','Area','Area code','Parking spots total']]
Traffic_Source.head()
# Out:
#   Geography                     Area Area code  Parking spots total
# 0    Wijken          Haarlemmerbuurt        AA                 1112
# 1    Wijken                  Jordaan        AB                 2711
# 2    Wijken      Grachtengordel-West        AC                 1338
# 3    Wijken  Burgwallen-Nieuwe Zijde        AD                  619
# 4    Wijken    Burgwallen-Oude Zijde        AE                  310

# %%
Income = pd.read_csv(folder_dir+'\\Income.csv', encoding='utf-8')
Income.head()
# Out:
#   Geography                     Area Area code  Year   theme  \
# 0    Wijken          Haarlemmerbuurt        AA  2021  Income
# 1    Wijken                  Jordaan        AB  2021  Income
# 2    Wijken      Grachtengordel-West        AC  2021  Income
# 3    Wijken  Burgwallen-Nieuwe Zijde        AD  2021  Income
# 4    Wijken    Burgwallen-Oude Zijde        AE  2021  Income
#
#   Mean disposable household income Income 1st quintile Income 2nd quintile  \
# 0                            49800                  30                  20
# 1                            46700                  33                  20
# 2                            83300                  20                  16
# 3                            44300                  32                  21
# 4                            40800                  35                  22
#
#   Income 3rd quintile Income 4th quintile  ...  \
# 0                  17                  13  ...
# 1                  17                  13  ...
# 2                  15                  16  ...
# 3                  19                  13  ...
# 4                  16                  13  ...
#
#   Househoulds children social welfare benefits  \
# 0                                           50
# 1                                           55
# 2                                            -
# 3                                            -
# 4                                           15
#
#   % Househoulds children social welfare benefits Disability benefits  \
# 0                                            7.4                 330
# 1                                            4.7                 690
# 2                                              -                  80
# 3                                              -                  60
# 4                                            8.6                  70
#
#   Disability benefits (%) Unemployment benefits Unemployment benefits (%)  \
# 0                     4.9                   200                         3
# 1                     4.7                   510                       3.4
# 2                     1.6                    90                       1.8
# 3                     1.7                   130                       3.7
# 4                     1.8                   130                       3.3
#
#   % economically independent men % economically indepdent women  \
# 0                             68                             62
# 1                             67                             63
# 2                             70                             61
# 3                             69                             63
# 4                             66                             54
#
#   Social welfare Social welfare (%)
# 0              -                  -
# 1              -                  -
# 2              -                  -
# 3              -                  -
# 4              -                  -
#
# [5 rows x 30 columns]

# %%
Income_Source = Income[['Geography','Area','Area code','Mean disposable household income']]
Income_Source.head()
# Out:
#   Geography                     Area Area code  \
# 0    Wijken          Haarlemmerbuurt        AA
# 1    Wijken                  Jordaan        AB
# 2    Wijken      Grachtengordel-West        AC
# 3    Wijken  Burgwallen-Nieuwe Zijde        AD
# 4    Wijken    Burgwallen-Oude Zijde        AE
#
#   Mean disposable household income
# 0                            49800
# 1                            46700
# 2                            83300
# 3                            44300
# 4                            40800

# %%
Socio_economic_status = pd.read_csv(folder_dir+'\\Socio-economic status.csv', encoding='utf-8')
Socio_economic_status.head()
# Out:
#   Geography                     Area Area code  Year                 theme  \
# 0    Wijken          Haarlemmerbuurt        AA  2021  Socioeconomic status
# 1    Wijken                  Jordaan        AB  2021  Socioeconomic status
# 2    Wijken      Grachtengordel-West        AC  2021  Socioeconomic status
# 3    Wijken  Burgwallen-Nieuwe Zijde        AD  2021  Socioeconomic status
# 4    Wijken    Burgwallen-Oude Zijde        AE  2021  Socioeconomic status
#
#   Social cohesion (1-10) SES low  SES midrange  SES high SES low (%)  ...  \
# 0                    6.2    2245          2385      4520          25  ...
# 1                    6.2    4560          5240      9555          24  ...
# 2                      6     970          1365      3970          15  ...
# 3                    5.4     890          1000      2095          22  ...
# 4                    5.6    1145          1125      2225          25  ...
#
#    Most vulnerable 0-17  Most vulnerable (% 0-17) Most vulnerable 18-26  \
# 0                    45                         4                    35
# 1                    55                         3                   100
# 2                    10                         2                    25
# 3                     -                         -                    20
# 4                     -                         -                    30
#
#   Most vulnerable (% 18-26) Most vulnerable 27-65 Most vulnerable (% 27-65)  \
# 0                         4                   520                         9
# 1                         4                  1105                         9
# 2                         3                   195                         5
# 3                         2                   190                         7
# 4                         3                   275                        10
#
#   Most vulnerable 66+ Most vulnerable (% 66+) Activities social participation  \
# 0                 335                      21                               -
# 1                 680                      22                               -
# 2                  80                       8                               -
# 3                  35                      12                               -
# 4                  80                      19                               -
#
#   Activities social participation / 1,000 inh.
# 0                                            -
# 1                                            -
# 2                                            -
# 3                                            -
# 4                                            -
#
# [5 rows x 32 columns]

# %%
Socio_economic_status_Source = Socio_economic_status[['Geography','Area','Area code','Most vulnerable (%)']]
Socio_economic_status_Source.head()
# Out:
#   Geography                     Area Area code  Most vulnerable (%)
# 0    Wijken          Haarlemmerbuurt        AA                   46
# 1    Wijken                  Jordaan        AB                   46
# 2    Wijken      Grachtengordel-West        AC                   51
# 3    Wijken  Burgwallen-Nieuwe Zijde        AD                   47
# 4    Wijken    Burgwallen-Oude Zijde        AE                   42

# %%
Safety = pd.read_csv(folder_dir+'\\Safety.csv', encoding='utf-8')
Safety.head()
# Out:
#   Geography                     Area Area code  Year   theme  \
# 0    Wijken          Haarlemmerbuurt        AA  2021  Safety
# 1    Wijken                  Jordaan        AB  2021  Safety
# 2    Wijken      Grachtengordel-West        AC  2021  Safety
# 3    Wijken  Burgwallen-Nieuwe Zijde        AD  2021  Safety
# 4    Wijken    Burgwallen-Oude Zijde        AE  2021  Safety
#
#   Safety index: registered crime index Safety index: High Volume Crime  \
# 0                                   81                              77
# 1                                  123                             103
# 2                                   89                             109
# 3                                  210                             213
# 4                                  138                             137
#
#   Safety index: High Impact Crime Safety index: reported victimization index  \
# 0                              85                                         75
# 1                             145                                        111
# 2                              64                                        164
# 3                             206                                        154
# 4                             139                                        134
#
#   Safety index: reported victimization of High Volume Crimes  ...  \
# 0                                                 92          ...
# 1                                                 96          ...
# 2                                                223          ...
# 3                                                120          ...
# 4                                                101          ...
#
#   Nuisance: subletting tourists (%) Nuisance: tourists Nuisance: locals (%)  \
# 0                                11                 19                    8
# 1                                14                 23                    8
# 2                                18                 36                    8
# 3                                25                 39                   10
# 4                                22                 50                    9
#
#   Nuisance: bothered in the street (%) Nuisance:  youths congegrating (%)  \
# 0                                    3                                  9
# 1                                    4                                 10
# 2                                    5                                  6
# 3                                    7                                 16
# 4                                   26                                 20
#
#   Nuisance: noise (%) Nuisance: neighbours (1-10)  \
# 0                  17                         7.5
# 1                  21                         7.2
# 2                  18                         7.4
# 3                  31                         6.8
# 4                  42                         7.4
#
#   Nuisance: other groups of people (1-10) Nuisance: catering (1-10)  \
# 0                                     7.2                       7.6
# 1                                       7                       7.2
# 2                                     7.1                       7.2
# 3                                     6.1                       5.8
# 4                                     5.8                       5.5
#
#   Victimization: sexual assault (%)
# 0                                 -
# 1                                 1
# 2                                 4
# 3                                 8
# 4                                 1
#
# [5 rows x 61 columns]

# %%
Safety_Source = Safety[['Geography','Area','Area code','Safety index: High Impact Crime']]
Safety_Source.head()
# Out:
#   Geography                     Area Area code Safety index: High Impact Crime
# 0    Wijken          Haarlemmerbuurt        AA                              85
# 1    Wijken                  Jordaan        AB                             145
# 2    Wijken      Grachtengordel-West        AC                              64
# 3    Wijken  Burgwallen-Nieuwe Zijde        AD                             206
# 4    Wijken    Burgwallen-Oude Zijde        AE                             139

# %%
import geopandas as gpd

# %%
Main_dataset = gpd.read_file(folder_dir+'\\Geometry of Wijks.csv', 
                    GEOM_POSSIBLE_NAMES="geometry", 
                    KEEP_GEOM_COLUMNS="NO")

# %%
Main_dataset['CBS_Wijkcode'] = Main_dataset['CBS_Wijkcode'].str.strip('"')
Main_dataset['Wijkcode'] = Main_dataset['Wijkcode'].str.strip('"')
Main_dataset['Wijk'] = Main_dataset['Wijk'].str.strip('"')
Main_dataset['Gebiedcode'] = Main_dataset['Gebiedcode'].str.strip('"')
Main_dataset['Gebied'] = Main_dataset['Gebied'].str.strip('"')
Main_dataset['Stadsdeelcode'] = Main_dataset['Stadsdeelcode'].str.strip('"')
Main_dataset['Stadsdeel'] = Main_dataset['Stadsdeel'].str.strip('"')

# change the header name or dtype
Main_dataset.rename(columns={'Wijkcode': 'Area code', 'Wijk': 'Area'}, inplace=True)

Main_dataset.head()
# Out:
#   OBJECTNUMMER CBS_Wijkcode Area code                Area Gebiedcode  \
# 0            1     BU0363EQ        EQ       Da Costabuurt       GE05
# 1            2     BU0363ER        ER  Westindische Buurt       GE05
# 2            3     BU0363KB        KB       Schinkelbuurt       GK11
# 3            4     BU0363KC        KC         Willemspark       GK11
# 4            5     BU0363KD        KD      Museumkwartier       GK11
#
#                   Gebied Stadsdeelcode Stadsdeel Oppervlakte_m2  \
# 0  Oud-West, De Baarsjes             E      West         257542
# 1  Oud-West, De Baarsjes             E      West         345503
# 2               Oud-Zuid             K      Zuid         344932
# 3               Oud-Zuid             K      Zuid         695818
# 4               Oud-Zuid             K      Zuid        1380178
#
#                                          WKT_LNG_LAT  \
# 0  POLYGON((4.867406 52.371797,4.869586 52.368605...
# 1  POLYGON((4.848885 52.358045,4.848892 52.357914...
# 2  POLYGON((4.848181 52.342768,4.849791 52.342924...
# 3  POLYGON((4.855085 52.35641,4.855027 52.356322,...
# 4  POLYGON((4.86554 52.358854,4.867135 52.356104,...
#
#                                          WKT_LAT_LNG        LNG         LAT  \
# 0  "POLYGON((52.371797 4.867406,52.368605 4.86958...  4.8721075    52.37013
# 1  "POLYGON((52.358045 4.848885,52.357914 4.84889...   4.854062   52.361007
# 2  "POLYGON((52.342768 4.848181,52.342924 4.84979...   4.852877  52.3496455
# 3  "POLYGON((52.35641 4.855085,52.356322 4.855027...  4.8627965   52.354371
# 4  "POLYGON((52.358854 4.86554,52.356104 4.867135...  4.8764645   52.355265
#
#                                             geometry
# 0  POLYGON ((4.86741 52.37180, 4.86959 52.36861, ...
# 1  POLYGON ((4.84889 52.35804, 4.84889 52.35791, ...
# 2  POLYGON ((4.84818 52.34277, 4.84979 52.34292, ...
# 3  POLYGON ((4.85508 52.35641, 4.85503 52.35632, ...
# 4  POLYGON ((4.86554 52.35885, 4.86714 52.35610, ...

# %%
# merge the dataset based on common column 'Area code'
merged_gdf = Main_dataset.merge(Rent_Average_Source[['Area code', 'Rent: average','Average house-value for tax purposes']], on='Area code', how='left')
merged_gdf.head()
# Out:
#   OBJECTNUMMER CBS_Wijkcode Area code                Area Gebiedcode  \
# 0            1     BU0363EQ        EQ       Da Costabuurt       GE05
# 1            2     BU0363ER        ER  Westindische Buurt       GE05
# 2            3     BU0363KB        KB       Schinkelbuurt       GK11
# 3            4     BU0363KC        KC         Willemspark       GK11
# 4            5     BU0363KD        KD      Museumkwartier       GK11
#
#                   Gebied Stadsdeelcode Stadsdeel Oppervlakte_m2  \
# 0  Oud-West, De Baarsjes             E      West         257542
# 1  Oud-West, De Baarsjes             E      West         345503
# 2               Oud-Zuid             K      Zuid         344932
# 3               Oud-Zuid             K      Zuid         695818
# 4               Oud-Zuid             K      Zuid        1380178
#
#                                          WKT_LNG_LAT  \
# 0  POLYGON((4.867406 52.371797,4.869586 52.368605...
# 1  POLYGON((4.848885 52.358045,4.848892 52.357914...
# 2  POLYGON((4.848181 52.342768,4.849791 52.342924...
# 3  POLYGON((4.855085 52.35641,4.855027 52.356322,...
# 4  POLYGON((4.86554 52.358854,4.867135 52.356104,...
#
#                                          WKT_LAT_LNG        LNG         LAT  \
# 0  "POLYGON((52.371797 4.867406,52.368605 4.86958...  4.8721075    52.37013
# 1  "POLYGON((52.358045 4.848885,52.357914 4.84889...   4.854062   52.361007
# 2  "POLYGON((52.342768 4.848181,52.342924 4.84979...   4.852877  52.3496455
# 3  "POLYGON((52.35641 4.855085,52.356322 4.855027...  4.8627965   52.354371
# 4  "POLYGON((52.358854 4.86554,52.356104 4.867135...  4.8764645   52.355265
#
#                                             geometry Rent: average  \
# 0  POLYGON ((4.86741 52.37180, 4.86959 52.36861, ...           823
# 1  POLYGON ((4.84889 52.35804, 4.84889 52.35791, ...           861
# 2  POLYGON ((4.84818 52.34277, 4.84979 52.34292, ...           774
# 3  POLYGON ((4.85508 52.35641, 4.85503 52.35632, ...          1349
# 4  POLYGON ((4.86554 52.35885, 4.86714 52.35610, ...          1051
#
#   Average house-value for tax purposes
# 0                               498536
# 1                               443995
# 2                               445304
# 3                              1064407
# 4                              1011630

# %%
merged_gdf = merged_gdf.merge(Public_Spaces_Source[['Area code', 'Area public green (ha)']], on='Area code', how='left')
merged_gdf = merged_gdf.merge(Traffic_Source[['Area code', 'Parking spots total']], on='Area code', how='left')
merged_gdf = merged_gdf.merge(Income_Source[['Area code', 'Mean disposable household income']], on='Area code', how='left')
merged_gdf = merged_gdf.merge(Socio_economic_status[['Area code', 'Most vulnerable (%)']], on='Area code', how='left')
merged_gdf = merged_gdf.merge(Safety_Source[['Area code', 'Safety index: High Impact Crime']], on='Area code', how='left')

merged_gdf.head()
# Out:
#   OBJECTNUMMER CBS_Wijkcode Area code                Area Gebiedcode  \
# 0            1     BU0363EQ        EQ       Da Costabuurt       GE05
# 1            2     BU0363ER        ER  Westindische Buurt       GE05
# 2            3     BU0363KB        KB       Schinkelbuurt       GK11
# 3            4     BU0363KC        KC         Willemspark       GK11
# 4            5     BU0363KD        KD      Museumkwartier       GK11
#
#                   Gebied Stadsdeelcode Stadsdeel Oppervlakte_m2  \
# 0  Oud-West, De Baarsjes             E      West         257542
# 1  Oud-West, De Baarsjes             E      West         345503
# 2               Oud-Zuid             K      Zuid         344932
# 3               Oud-Zuid             K      Zuid         695818
# 4               Oud-Zuid             K      Zuid        1380178
#
#                                          WKT_LNG_LAT  ...        LNG  \
# 0  POLYGON((4.867406 52.371797,4.869586 52.368605...  ...  4.8721075
# 1  POLYGON((4.848885 52.358045,4.848892 52.357914...  ...   4.854062
# 2  POLYGON((4.848181 52.342768,4.849791 52.342924...  ...   4.852877
# 3  POLYGON((4.855085 52.35641,4.855027 52.356322,...  ...  4.8627965
# 4  POLYGON((4.86554 52.358854,4.867135 52.356104,...  ...  4.8764645
#
#           LAT                                           geometry  \
# 0    52.37013  POLYGON ((4.86741 52.37180, 4.86959 52.36861, ...
# 1   52.361007  POLYGON ((4.84889 52.35804, 4.84889 52.35791, ...
# 2  52.3496455  POLYGON ((4.84818 52.34277, 4.84979 52.34292, ...
# 3   52.354371  POLYGON ((4.85508 52.35641, 4.85503 52.35632, ...
# 4   52.355265  POLYGON ((4.86554 52.35885, 4.86714 52.35610, ...
#
#   Rent: average Average house-value for tax purposes Area public green (ha)  \
# 0           823                               498536                   0.68
# 1           861                               443995                   2.01
# 2           774                               445304                    1.8
# 3          1349                              1064407                  16.38
# 4          1051                              1011630                  17.53
#
#   Parking spots total  Mean disposable household income Most vulnerable (%)  \
# 0               971.0                             49800                52.0
# 1              1763.0                             50500                54.0
# 2               972.0                             46200                51.0
# 3              2624.0                            131700                55.0
# 4              4839.0                            103000                55.0
#
#    Safety index: High Impact Crime
# 0                              130
# 1                               89
# 2                              104
# 3                               51
# 4                              219
#
# [5 rows x 21 columns]

# %%
merged = merged_gdf[['OBJECTNUMMER','CBS_Wijkcode','Area code','Area','Rent: average','Average house-value for tax purposes','Area public green (ha)','Parking spots total','Mean disposable household income','Most vulnerable (%)','Safety index: High Impact Crime','geometry','LNG','LAT','Gebiedcode','Gebied','Stadsdeelcode','Stadsdeel','Oppervlakte_m2']]
merged.head()
# Out:
#   OBJECTNUMMER CBS_Wijkcode Area code                Area Rent: average  \
# 0            1     BU0363EQ        EQ       Da Costabuurt           823
# 1            2     BU0363ER        ER  Westindische Buurt           861
# 2            3     BU0363KB        KB       Schinkelbuurt           774
# 3            4     BU0363KC        KC         Willemspark          1349
# 4            5     BU0363KD        KD      Museumkwartier          1051
#
#   Average house-value for tax purposes Area public green (ha)  \
# 0                               498536                   0.68
# 1                               443995                   2.01
# 2                               445304                    1.8
# 3                              1064407                  16.38
# 4                              1011630                  17.53
#
#    Parking spots total Mean disposable household income  Most vulnerable (%)  \
# 0                971.0                            49800                 52.0
# 1               1763.0                            50500                 54.0
# 2                972.0                            46200                 51.0
# 3               2624.0                           131700                 55.0
# 4               4839.0                           103000                 55.0
#
#   Safety index: High Impact Crime  \
# 0                             130
# 1                              89
# 2                             104
# 3                              51
# 4                             219
#
#                                             geometry        LNG         LAT  \
# 0  POLYGON ((4.86741 52.37180, 4.86959 52.36861, ...  4.8721075    52.37013
# 1  POLYGON ((4.84889 52.35804, 4.84889 52.35791, ...   4.854062   52.361007
# 2  POLYGON ((4.84818 52.34277, 4.84979 52.34292, ...   4.852877  52.3496455
# 3  POLYGON ((4.85508 52.35641, 4.85503 52.35632, ...  4.8627965   52.354371
# 4  POLYGON ((4.86554 52.35885, 4.86714 52.35610, ...  4.8764645   52.355265
#
#   Gebiedcode                 Gebied Stadsdeelcode Stadsdeel Oppervlakte_m2
# 0       GE05  Oud-West, De Baarsjes             E      West         257542
# 1       GE05  Oud-West, De Baarsjes             E      West         345503
# 2       GK11               Oud-Zuid             K      Zuid         344932
# 3       GK11               Oud-Zuid             K      Zuid         695818
# 4       GK11               Oud-Zuid             K      Zuid        1380178

# %%
merged.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 111 entries, 0 to 110
# Data columns (total 19 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   OBJECTNUMMER                          111 non-null    object
#  1   CBS_Wijkcode                          111 non-null    object
#  2   Area code                             111 non-null    object
#  3   Area                                  111 non-null    object
#  4   Rent: average                         105 non-null    object
#  5   Average house-value for tax purposes  105 non-null    object
#  6   Area public green (ha)                105 non-null    object
#  7   Parking spots total                   103 non-null    float64
#  8   Mean disposable household income      104 non-null    object
#  9   Most vulnerable (%)                   105 non-null    float64
#  10  Safety index: High Impact Crime       99 non-null     object
#  11  geometry                              110 non-null    geometry
#  12  LNG                                   111 non-null    object
#  13  LAT                                   111 non-null    object
#  14  Gebiedcode                            111 non-null    object
#  15  Gebied                                111 non-null    object
#  16  Stadsdeelcode                         111 non-null    object
#  17  Stadsdeel                             111 non-null    object
#  18  Oppervlakte_m2                        111 non-null    object
# dtypes: float64(2), geometry(1), object(16)
# memory usage: 16.6+ KB

# %%
merged['Rent: average'] = merged['Rent: average'].apply(pd.to_numeric, errors='coerce')
merged['Average house-value for tax purposes'] = merged['Average house-value for tax purposes'].apply(pd.to_numeric, errors='coerce')
merged['Area public green (ha)'] = merged['Area public green (ha)'].apply(pd.to_numeric, errors='coerce')
merged['Average house-value for tax purposes'] = merged['Average house-value for tax purposes'].apply(pd.to_numeric, errors='coerce')
merged['Mean disposable household income'] = merged['Mean disposable household income'].apply(pd.to_numeric, errors='coerce')
merged['Safety index: High Impact Crime'] = merged['Safety index: High Impact Crime'].apply(pd.to_numeric, errors='coerce')

merged.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 111 entries, 0 to 110
# Data columns (total 19 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   OBJECTNUMMER                          111 non-null    object
#  1   CBS_Wijkcode                          111 non-null    object
#  2   Area code                             111 non-null    object
#  3   Area                                  111 non-null    object
#  4   Rent: average                         69 non-null     float64
#  5   Average house-value for tax purposes  102 non-null    float64
#  6   Area public green (ha)                102 non-null    float64
#  7   Parking spots total                   103 non-null    float64
#  8   Mean disposable household income      102 non-null    float64
#  9   Most vulnerable (%)                   105 non-null    float64
#  10  Safety index: High Impact Crime       93 non-null     float64
#  11  geometry                              110 non-null    geometry
#  12  LNG                                   111 non-null    object
#  13  LAT                                   111 non-null    object
#  14  Gebiedcode                            111 non-null    object
#  15  Gebied                                111 non-null    object
#  16  Stadsdeelcode                         111 non-null    object
#  17  Stadsdeel                             111 non-null    object
#  18  Oppervlakte_m2                        111 non-null    object
# dtypes: float64(7), geometry(1), object(11)
# memory usage: 16.6+ KB
# c:\Users\Admin\.conda\envs\gds\lib\site-packages\geopandas\geodataframe.py:1528: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
# save the dataset
merged.to_file(folder_dir+'\\MergedData_Geo.shp')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_29432\3248435227.py:2: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   merged.to_file(folder_dir+'\\MergedData_Geo.shp')

# %%
import contextily as ctx
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
# load the geo file

file_path = 'C:\\Users\\Admin\\Desktop\\Code\\Assignment-1\\Hackathon\\csv\\MergedData_Geo.shp'
dataset = gpd.read_file(file_path)
dataset.head()
# Out:
#   OBJECTNUMM CBS_Wijkco Area code                Area  Rent_ aver  Average ho  \
# 0          1   BU0363EQ        EQ       Da Costabuurt       823.0    498536.0
# 1          2   BU0363ER        ER  Westindische Buurt       861.0    443995.0
# 2          3   BU0363KB        KB       Schinkelbuurt       774.0    445304.0
# 3          4   BU0363KC        KC         Willemspark      1349.0   1064407.0
# 4          5   BU0363KD        KD      Museumkwartier      1051.0   1011630.0
#
#    Area publi  Parking sp  Mean dispo  Most vulne  Safety ind        LNG  \
# 0        0.68       971.0     49800.0        52.0       130.0  4.8721075
# 1        2.01      1763.0     50500.0        54.0        89.0   4.854062
# 2        1.80       972.0     46200.0        51.0       104.0   4.852877
# 3       16.38      2624.0    131700.0        55.0        51.0  4.8627965
# 4       17.53      4839.0    103000.0        55.0       219.0  4.8764645
#
#           LAT Gebiedcode                 Gebied Stadsdeelc Stadsdeel  \
# 0    52.37013       GE05  Oud-West, De Baarsjes          E      West
# 1   52.361007       GE05  Oud-West, De Baarsjes          E      West
# 2  52.3496455       GK11               Oud-Zuid          K      Zuid
# 3   52.354371       GK11               Oud-Zuid          K      Zuid
# 4   52.355265       GK11               Oud-Zuid          K      Zuid
#
#   Oppervlakt                                           geometry
# 0     257542  POLYGON ((4.86741 52.37180, 4.87549 52.37341, ...
# 1     345503  POLYGON ((4.84889 52.35804, 4.84889 52.36076, ...
# 2     344932  POLYGON ((4.84818 52.34277, 4.84882 52.34344, ...
# 3     695818  POLYGON ((4.85508 52.35641, 4.85894 52.35741, ...
# 4    1380178  POLYGON ((4.86554 52.35885, 4.86580 52.35882, ...

# %%
print(dataset.columns.tolist())
# Out:
# ['OBJECTNUMM', 'CBS_Wijkco', 'Area code', 'Area', 'Rent_ aver', 'Average ho', 'Area publi', 'Parking sp', 'Mean dispo', 'Most vulne', 'Safety ind', 'LNG', 'LAT', 'Gebiedcode', 'Gebied', 'Stadsdeelc', 'Stadsdeel', 'Oppervlakt', 'geometry']

# %%
dataset.rename(columns={'OBJECTNUMM':'OBJECTNUMMER', 'CBS_Wijkco':'CBS_Wijkcode', 'Rent_ aver':'Rent_average', 'Average ho':'Average house-value for tax purposes', 'Area publi':'Area public green (ha)', 'Parking sp':'Parking spots total', 'Mean dispo':'Mean disposable household income', 'Most vulne':'Most vulnerable (%)', 'Safety ind':'Safety index: High Impact Crime', 'Stadsdeelc':'Stadsdeelcode', 'Oppervlakt':'Oppervlakte_m2'}, inplace=True)

# %%
dataset.head()
# Out:
#   OBJECTNUMMER CBS_Wijkcode Area code                Area  Rent_average  \
# 0            1     BU0363EQ        EQ       Da Costabuurt         823.0
# 1            2     BU0363ER        ER  Westindische Buurt         861.0
# 2            3     BU0363KB        KB       Schinkelbuurt         774.0
# 3            4     BU0363KC        KC         Willemspark        1349.0
# 4            5     BU0363KD        KD      Museumkwartier        1051.0
#
#    Average house-value for tax purposes  Area public green (ha)  \
# 0                              498536.0                    0.68
# 1                              443995.0                    2.01
# 2                              445304.0                    1.80
# 3                             1064407.0                   16.38
# 4                             1011630.0                   17.53
#
#    Parking spots total  Mean disposable household income  Most vulnerable (%)  \
# 0                971.0                           49800.0                 52.0
# 1               1763.0                           50500.0                 54.0
# 2                972.0                           46200.0                 51.0
# 3               2624.0                          131700.0                 55.0
# 4               4839.0                          103000.0                 55.0
#
#    Safety index: High Impact Crime        LNG         LAT Gebiedcode  \
# 0                            130.0  4.8721075    52.37013       GE05
# 1                             89.0   4.854062   52.361007       GE05
# 2                            104.0   4.852877  52.3496455       GK11
# 3                             51.0  4.8627965   52.354371       GK11
# 4                            219.0  4.8764645   52.355265       GK11
#
#                   Gebied Stadsdeelcode Stadsdeel Oppervlakte_m2  \
# 0  Oud-West, De Baarsjes             E      West         257542
# 1  Oud-West, De Baarsjes             E      West         345503
# 2               Oud-Zuid             K      Zuid         344932
# 3               Oud-Zuid             K      Zuid         695818
# 4               Oud-Zuid             K      Zuid        1380178
#
#                                             geometry
# 0  POLYGON ((4.86741 52.37180, 4.87549 52.37341, ...
# 1  POLYGON ((4.84889 52.35804, 4.84889 52.36076, ...
# 2  POLYGON ((4.84818 52.34277, 4.84882 52.34344, ...
# 3  POLYGON ((4.85508 52.35641, 4.85894 52.35741, ...
# 4  POLYGON ((4.86554 52.35885, 4.86580 52.35882, ...

# %%
# Add background map, expressing target CRS so the basemap can be reprojected (warped)
ax = dataset.plot(figsize=(9,9), alpha=0.5, color='yellow');
ctx.add_basemap(ax, crs=dataset.crs)
# Out:
# c:\Users\Admin\.conda\envs\gds\lib\site-packages\contextily\tile.py:645: UserWarning: The inferred zoom level of 28 is not valid for the current tile provider (valid zooms: 0 - 19).
#   warnings.warn(msg)

# %%
# Set up figure and axis
f, ax = plt.subplots(1, figsize=(9, 9)) 

# Plot '% to leave' and 'Valid_Vote'
# First plot: '% to Leave'
# dataset.plot(column='Pct_Leave', scheme='Quantiles', legend=True, ax=ax1)
# ax1.set_title('% to Leave')
# remove axis frame
# ax1.set_axis_off()
# Add background map
# ctx.add_basemap(ax1, crs=dataset.crs)

# Second plot: 'Rent: average'
dataset.plot(column='Rent_average', cmap='plasma', legend=True, ax=ax, 
             legend_kwds={
                 'shrink': 0.2, 'fraction': 0.1,  # the size of colorbar: 20%
                 'label': "Number",  # Add legend to colorbar
                 'orientation': "vertical",  # or set 'horizontal'
                 #'aspect': 50 # aspect ratio
         })
ax.set_title('Rent: average')
ax.set_axis_off()

# Add background map
ctx.add_basemap(ax, crs=dataset.crs)

# Title
# f.suptitle('Title_Name', size=30)
# Change background color of the figure
f.set_facecolor('0.75')

# Adjust layout
plt.tight_layout()
# Draw
plt.show()
# Out:
# c:\Users\Admin\.conda\envs\gds\lib\site-packages\contextily\tile.py:645: UserWarning: The inferred zoom level of 29 is not valid for the current tile provider (valid zooms: 0 - 19).
#   warnings.warn(msg)
