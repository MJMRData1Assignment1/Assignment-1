# %% [markdown]
# Clean the dataset with Geopandas

# %%
import geopandas as gpd

# %%
file_path = 'C:\\Users\\Admin\\Desktop\\Code\\brexit.gpkg'

# %%
dataset = gpd.read_file(file_path).set_index('LAD14CD', drop=False)

# %%
dataset.head()
# Out:
#            OBJECTID    LAD14CD               LAD14NM LAD14NMW  id Region_Cod  \
# LAD14CD
# E06000001         1  E06000001            Hartlepool      NaN  70  E12000001
# E06000002         2  E06000002         Middlesbrough      NaN  71  E12000001
# E06000003         3  E06000003  Redcar and Cleveland      NaN  72  E12000001
# E06000004         4  E06000004      Stockton-on-Tees      NaN  73  E12000001
# E06000005         5  E06000005            Darlington      NaN  74  E12000001
#
#                Region                  Area  Electorate  ExpectedBa  ...  \
# LAD14CD                                                              ...
# E06000001  North East            Hartlepool       70341       46137  ...
# E06000002  North East         Middlesbrough       94612       61395  ...
# E06000003  North East  Redcar and Cleveland      103529       72741  ...
# E06000004  North East      Stockton-on-Tees      141486      100462  ...
# ...

# %%
# check all headers
# print(dataset.columns)

columns_list = list(dataset.columns)
columns_list
# Out:
# ['OBJECTID',
#  'LAD14CD',
#  'LAD14NM',
#  'LAD14NMW',
#  'id',
#  'Region_Cod',
#  'Region',
#  'Area',
#  'Electorate',
#  'ExpectedBa',
#  'VerifiedBa',
#  'Pct_Turnou',
#  'Votes_Cast',
#  'Valid_Vote',
#  'Remain',
#  'Leave',
#  'Rejected_B',
#  'No_officia',
#  'Voting_for',
#  'Writing_or',
#  'Unmarked_o',
#  'Pct_Remain',
#  'Pct_Leave',
#  'Pct_Reject',
#  'geometry']

# %%
# check the data
dataset.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 380 entries, E06000001 to W06000024
# Data columns (total 25 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OBJECTID    380 non-null    int64
#  1   LAD14CD     380 non-null    object
#  2   LAD14NM     380 non-null    object
#  3   LAD14NMW    22 non-null     object
#  4   id          380 non-null    int64
#  5   Region_Cod  380 non-null    object
#  6   Region      380 non-null    object
#  7   Area        380 non-null    object
#  8   Electorate  380 non-null    int64
#  9   ExpectedBa  380 non-null    int64
#  10  VerifiedBa  380 non-null    int64
#  11  Pct_Turnou  380 non-null    float64
#  12  Votes_Cast  380 non-null    int64
#  13  Valid_Vote  380 non-null    int64
#  14  Remain      380 non-null    int64
#  15  Leave       380 non-null    int64
#  16  Rejected_B  380 non-null    int64
#  17  No_officia  380 non-null    int64
#  18  Voting_for  380 non-null    int64
# ...

# %%
dataset.describe()
# Out:
#          OBJECTID          id     Electorate     ExpectedBa     VerifiedBa  \
# count  380.000000  380.000000     380.000000     380.000000     380.000000
# mean   190.500000  190.500000  118986.650000   86233.350000   86229.847368
# std    109.840794  109.840794   77547.729443   52439.419878   52436.123907
# min      1.000000    1.000000    1799.000000    1424.000000    1424.000000
# 25%     95.750000   95.750000   72597.250000   54907.500000   54904.500000
# 50%    190.500000  190.500000   96425.500000   72544.500000   72544.000000
# 75%    285.250000  285.250000  141167.250000  103691.500000  103691.500000
# max    380.000000  380.000000  707293.000000  451422.000000  451336.000000
#
#        Pct_Turnou     Votes_Cast     Valid_Vote         Remain          Leave  \
# count  380.000000     380.000000     380.000000     380.000000     380.000000
# mean    73.757868   86228.018421   86162.339474   41266.347368   44895.992105
# ...

# %% [markdown]
# Set the columns

# %%
# change the header name or dtype
# dataset.rename(columns={'sl__no_': 'Column1', 'state_ut': 'Column2', 'vaccine_doses_supplied':'Column3'}, inplace=True)

# select columns
# dataset = dataset[['Column1','Column2','Column3']]

# %% [markdown]
# Transform the datatype

# %%
# To integer
# dataset['column_name'] = dataset['column_name'].astype(int)

# To strings
# dataset['column_name'] = dataset['column_name'].astype(str)

# To datatime
# dataset['date_column'] = gpd.to_datetime(dataset['date_column'])

# Check dtypes
# print(dataset.dtypes)

# %% [markdown]
# Deal with the missing data

# %%
#Try to locate where the missing values occur
dataset[dataset.LAD14NMW.isnull()]
# Out:
#            OBJECTID    LAD14CD               LAD14NM LAD14NMW   id Region_Cod  \
# LAD14CD
# E06000001         1  E06000001            Hartlepool      NaN   70  E12000001
# E06000002         2  E06000002         Middlesbrough      NaN   71  E12000001
# E06000003         3  E06000003  Redcar and Cleveland      NaN   72  E12000001
# E06000004         4  E06000004      Stockton-on-Tees      NaN   73  E12000001
# E06000005         5  E06000005            Darlington      NaN   74  E12000001
# ...             ...        ...                   ...      ...  ...        ...
# S12000041       354  S12000041                 Angus      NaN  150  S92000003
# S12000042       355  S12000042           Dundee City      NaN  156  S92000003
# S12000044       356  S12000044     North Lanarkshire      NaN  170  S92000003
# S12000045       357  S12000045   East Dunbartonshire      NaN  158  S92000003
# S12000046       358  S12000046          Glasgow City      NaN  164  S92000003
#
# ...

# %%
# drop missing values
# dataset.dropna()

# fill missing values with 'new_value'
# dataset['column_name'] = dataset['column_name'].fillna('new_value')

# %%
# (WARN: from chatGPT)

# Check whether polygen is valid
# gdf = gdf[gdf.is_valid]  # filter valid polygen

# fix unvalid polygen
# gdf['geometry'] = gdf['geometry'].buffer(0)

# %% [markdown]
# Change the cell content

# %%
# if/else statement:
# Refer: Assignment2 Question4 

# sort and groupby
# Refer: Lab03, Assignment3

# %% [markdown]
# Save cleaned dataset file

# %%
# save the dataset
# dataset.to_file(newfile_path)
